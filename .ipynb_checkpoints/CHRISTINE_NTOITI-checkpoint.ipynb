# %% [markdown]
# #### 1. Data Preparation
# ##### 1.1 Import the Libraries

# %%
# Import the libraries
from zipfile import ZipFile
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV 
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier 
from xgboost import XGBClassifier
import re
import nltk
# nltk.download('stopwords')
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import spacy
from wordcloud import WordCloud

# %% [markdown]
# ##### 1.2 Load the Dataset

# %%
# Extract the zip file
with ZipFile("../Dreams_raw_dataset.zip", 'r') as f:
    f.extractall()

# Read the CSV file as a single column
dreams_df = pd.read_csv("dreams_raw_dataset.csv")
dreams_df.head(5)
# Out:
#   date_of_birth date_of_enrollment   county head_of_household  \
# 0     9/16/2004          2/22/2020  Nairobi            Mother
# 1      8/2/2004         12/18/2019  Nairobi            Father
# 2    10/20/2005           3/7/2020  Nairobi            Mother
# 3     1/18/2006           3/3/2020  Nairobi            Mother
# 4     3/22/2004         12/18/2019  Nairobi            Father
#
#   head_of_household_other  age_of_household_head father_alive mother_alive  \
# 0                     NaN                   58.0          Yes          Yes
# 1                     NaN                   43.0          Yes          Yes
# 2                     NaN                   41.0           No          Yes
# 3                     NaN                   45.0           No          Yes
# 4                     NaN                   42.0          Yes          Yes
#
#   are_both_parents_alive is_one_parent_alive  ...   intervention_name  \
# ...

# %% [markdown]
# ##### 1.3. Initial Dataset Exploration
# Display the number of rows and columns in the dataset and list all the column names in the dataset.

# %%
# check the shape of the dataset
print(f'The shape of the dataset is {dreams_df.shape}')

print(dreams_df.columns)

print(f'The Target Variable is result')
# Out:
# The shape of the dataset is (455807, 42)
# Index(['date_of_birth', 'date_of_enrollment', 'county', 'head_of_household',
#        'head_of_household_other', 'age_of_household_head', 'father_alive',
#        'mother_alive', 'are_both_parents_alive', 'is_one_parent_alive',
#        'parents_alive_status', 'no_of_people_in_household', 'no_of_females',
#        'no_of_males', 'no_of_adults', 'no_of_children',
#        'ever_missed_full_day_food_in_4wks', 'no_of_days_missed_food_in_4wks',
#        'currently_in_school', 'current_school_level', 'current_income_source',
#        'ever_tested_for_hiv', 'last_test_result', 'ever_had_sex',
#        'age_at_first_sexual_encounter', 'has_sexual_partner',
#        'age_of_last_partner', 'used_condom_with_last_partner',
#        'dreams_program', 'dreams_program_other', 'exit_status', 'exit_reason',
#        'intervention_name', 'intervention_date', 'result', 'bio_medical',
#        'social_protection', 'behavioral', 'post_gbv_care',
# ...

# %% [markdown]
# ##### 1.4. Handle missing values
# Calculate the percentage of missing values for each column to understand the quality of the dataset.

# %%
# Calculate the percentage of missing values for each column
missing_data_percentage = (dreams_df.isnull().mean() * 100).round(2)
print(missing_data_percentage)

# Create a barplot to visualize the percentage of missing values
plt.figure(figsize=(8,4))
sns.barplot(x=missing_data_percentage.index, y=missing_data_percentage.values, color='purple')
plt.xticks(rotation=90)
plt.xlabel('Columns')
plt.ylabel('Percentage of Missing Values')
plt.title('Percentage of Missing Values per Column')

# Set y-axis limit from 0 to 100
plt.ylim(0, 100)

plt.show()
# Out:
# date_of_birth                         0.00
# date_of_enrollment                    0.00
# county                                2.03
# head_of_household                     2.11
# head_of_household_other              98.69
# age_of_household_head                 4.61
# father_alive                          2.94
# mother_alive                          2.85
# are_both_parents_alive                0.00
# is_one_parent_alive                   0.00
# parents_alive_status                 14.35
# no_of_people_in_household             1.58
# no_of_females                         1.61
# no_of_males                           1.69
# no_of_adults                          1.64
# no_of_children                        1.71
# ever_missed_full_day_food_in_4wks     1.57
# no_of_days_missed_food_in_4wks       43.67
# currently_in_school                   0.92
# current_school_level                 44.07
# current_income_source                28.43
# ever_tested_for_hiv                   0.00
# ...

# %% [markdown]
# ##### 1.5. Categorical and Numerical Columns
# Check the data types of our columns

# %%
# Identify categorical columns (dtype = object or category)
categorical_columns = dreams_df.select_dtypes(include=['object', 'category']).columns

print("Categorical columns:", categorical_columns)

# Identify categorical columns (dtype = object or category)
numerical_columns = dreams_df.select_dtypes(include=['float64', 'int64']).columns

print("numerical columns:", numerical_columns)
# Out:
# Categorical columns: Index(['date_of_birth', 'date_of_enrollment', 'county', 'head_of_household',
#        'head_of_household_other', 'father_alive', 'mother_alive',
#        'are_both_parents_alive', 'is_one_parent_alive', 'parents_alive_status',
#        'ever_missed_full_day_food_in_4wks', 'no_of_days_missed_food_in_4wks',
#        'currently_in_school', 'current_school_level', 'current_income_source',
#        'ever_tested_for_hiv', 'last_test_result', 'ever_had_sex',
#        'has_sexual_partner', 'age_of_last_partner',
#        'used_condom_with_last_partner', 'dreams_program',
#        'dreams_program_other', 'exit_status', 'exit_reason',
#        'intervention_name', 'intervention_date', 'result',
#        'exit_reason_other'],
#       dtype='object')
# numerical columns: Index(['age_of_household_head', 'no_of_people_in_household', 'no_of_females',
#        'no_of_males', 'no_of_adults', 'no_of_children',
# ...

# %% [markdown]
# ##### 1.6. Data cleaning and Preprocessing
# Carry out dData cleaning and preprocessing steps below to ensureihe datat is ready for analysis.
#
# Columns with more than 80% missing data (head_of_household_other columns with 98.69%, dreams_program column with 89.81%,
# dreams_program_othe column with  98.5%, and exit_reason_other column with 94.36%)  are a concern.
#
# All other columns will be imputed with appropriate strategies (median for numerical columns, and mode imputation for categorical columns).

# %%
# Drop columns with more than 80% missing values
# Filter columns where missing data is greater than 80%
columns_to_drop = missing_data_percentage[missing_data_percentage > 80].index

# Drop those columns from the DataFrame
dreams_df = dreams_df.drop(columns=columns_to_drop)

# Fill missing values in categorical columns with 'Unknown' and numerical columns with mode
for column in dreams_df.columns:
    if dreams_df[column].dtype == 'object':  # Categorical column
        dreams_df[column] = dreams_df[column].fillna('Unknown')  # Fill ' '
    else:  # Numerical column
        dreams_df[column] = dreams_df[column].fillna(dreams_df[column].mode()[0])  # Fill with mode


# Check for any remaining missing values and handle
dreams_df.isnull().sum()


dreams_df.head(5)
# Out:
#   date_of_birth date_of_enrollment   county head_of_household  \
# 0     9/16/2004          2/22/2020  Nairobi            Mother
# 1      8/2/2004         12/18/2019  Nairobi            Father
# 2    10/20/2005           3/7/2020  Nairobi            Mother
# 3     1/18/2006           3/3/2020  Nairobi            Mother
# 4     3/22/2004         12/18/2019  Nairobi            Father
#
#    age_of_household_head father_alive mother_alive are_both_parents_alive  \
# 0                   58.0          Yes          Yes                    Yes
# 1                   43.0          Yes          Yes                    Yes
# 2                   41.0           No          Yes                     No
# 3                   45.0           No          Yes                     No
# 4                   42.0          Yes          Yes                    Yes
#
#   is_one_parent_alive parents_alive_status  ...  exit_reason  \
# 0                  No                 Both  ...
# ...

# %% [markdown]
# ##### 1.7. One-hot-encode the Target varibale 'result'

# %%
# # Clean the 'result' column by stripping extra spaces
# dreams_df['result'] = dreams_df['result'].str.strip()

# # One-hot encode the 'result' column
# result_encoded = pd.get_dummies(dreams_df['result'], prefix='result')

# # Append the one-hot encoded columns to the original DataFrame
# dreams_df_encoded = pd.concat([dreams_df, result_encoded], axis=1)

# dreams_df_encoded.head(5)

# %% [markdown]
# #### 2. Exploratory Data Analysis
# ##### 2.1 Visualizing the Distribution of the Target Variable 'result'
# The target variable 'result' likely indicates whether a client is hiv positive or negative

# %%
result = dreams_df['result']  

# Visualize the distribution of the 'result' column
plt.figure(figsize=(10, 6))
result.value_counts().plot(kind='bar', color='skyblue')  # Use value_counts() to get the count of each category
plt.title('Distribution of Target Variable: result')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Annotate the bars with the count values for clarity
for index, value in enumerate(result.value_counts()):
    plt.text(index, value + 2, str(value), ha='center', color='black')  # Adjust +2 for spacing above the bars

plt.show()

# %% [markdown]
# #### 2.2. Visualizing the 'result' against other categories

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def visualize_result_by_category(dreams_df, cat_variable, target_col='result'):
    """
    Visualizes the distribution of the 'result' column against a categorical variable.
    Annotates the bars with the count values for clarity.
    
    Parameters:
    dreams_df (DataFrame): The DataFrame containing the data.
    cat_variable (str): The categorical variable to compare 'result' against.
    target_col (str): The column representing the target variable, default is 'result'.
    
    Returns:
    None: Displays the plot.
    """
    # Strip any leading/trailing spaces in column names
    dreams_df.columns = dreams_df.columns.str.strip()
    
    # Check if the target column exists in the DataFrame
    if target_col not in dreams_df.columns:
        print(f"Warning: {target_col} does not exist in the DataFrame.")
        return

    # Visualize the distribution of 'result' by the categorical variable
    plt.figure(figsize=(12, 6))
    ax = sns.countplot(x=cat_variable, hue=target_col, data=dreams_df, palette='Set2')
    
    # Add the count at the end of each bar
    for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x() + p.get_width() / 2, height + 2,  # Positioning the text
                f'{int(height)}', ha='center', va='bottom', fontsize=12, color='black')  # Formatting text
    
    # Customize the plot
    plt.title(f'Distribution of {target_col} by {cat_variable}')
    plt.xlabel(cat_variable)
    plt.ylabel('Count')
    plt.xticks(rotation=90)

# %%
# Visualize the result category against the county
visualize_result_by_category(dreams_df, 'county')

# %%
# Visualize the result category against 'current_income_source'
visualize_result_by_category(dreams_df, 'current_income_source')

# %%
# Visualize the result category against 'currently_in_school'
visualize_result_by_category(dreams_df, 'currently_in_school')

# %%
# Visualize categorical columns
def visualize_categorical_distribution(dreams_df, cat_columns):
    """
    Visualizes the distribution of each categorical column in the DataFrame.
    """
    for col in cat_columns:
        plt.figure(figsize=(10, 6))
        sns.countplot(y=col, data=dreams_df, palette='Set2')
        plt.title(f'Distribution of {col}')
        plt.xlabel('Count')
        plt.ylabel(col)
        plt.show()

categorical_columns = ['county', 'head_of_household', 'parents_alive_status', 'currently_in_school', 'ever_tested_for_hiv', 'result']
visualize_categorical_distribution(dreams_df, categorical_columns)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_27060\417205517.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=dreams_df, palette='Set2')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_27060\417205517.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=dreams_df, palette='Set2')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_27060\417205517.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=dreams_df, palette='Set2')
# ...
